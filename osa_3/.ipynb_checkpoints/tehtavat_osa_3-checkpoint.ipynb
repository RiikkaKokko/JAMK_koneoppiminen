# %% [markdown]
# # Koneoppiminen: Osa 3: Naiivi Bayes-luokittelija

# %%
# Kirjoita tähän tietosi!
student_name = 'Riikka Kokko'
student_id = 'AA9067'

# %% [markdown]
# ## Tehtävä 1
# ### Aihe: Artificial Characters Data Set
#
# 4 pistettä
#
# 1. Tutustu *Wine Data Set* -aineistoon osoitteessa https://archive.ics.uci.edu/ml/datasets/Wine .
#
# 2. Lataa aineisto ja aseta sarakkeiden nimet.
#
# 3. Normalisoi sarakkeet välille 0...1 `scikit-learn`-kirjaston `preprocessing`-moduulin [minmax_scale](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.minmax_scale.html#sklearn.preprocessing.minmax_scale)-funktiolla.
#
# 4. Jaa aineisto koulutus- ja testausaineistoon käyttäen `scikit-learn`-kirjaston [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)-funktiota. Laita puolet aineistosta kumpaankin.
#
# - Tallenna koulutusaineisto ja sen luokkamuuttuja muuttujiin `X_train`, `y_train`,
# - ja toisaalta testausaineiston `X_test`, `y_test`.
#
# Aseta testausjoukon kooksi 33% ja satunnaisuuden siemeneksi `1900`.
#
# Vinkki: älä skaalaa luokkamuuttujaa.
#
# Vinkki: muista että luokkamuuttuja ei mene `X`-muuttujiin.

# %%
#Lataa aineisto ja aseta sarakkeiden nimet.
import pandas as pd
#df=pd.read_csv("seeds_dataset.txt", sep="\t", error_bad_lines=False)
df=pd.read_csv("wine.data", sep=",", delim_whitespace=False)
df.columns = ["class identifier", "Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", "Total phenols", "Flavanoids",  "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline"]

df.head()
# Out:
#    class identifier  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0                 1    13.20        1.78  2.14               11.2        100
# 1                 1    13.16        2.36  2.67               18.6        101
# 2                 1    14.37        1.95  2.50               16.8        113
# 3                 1    13.24        2.59  2.87               21.0        118
# 4                 1    14.20        1.76  2.45               15.2        112
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# 1             5.68  1.03                          3.17     1185
# 2             7.80  0.86                          3.45     1480
# 3             4.32  1.04                          2.93      735
# 4             6.75  1.05                          2.85     1450

# %%
#Jaa aineisto koulutus- ja testausaineistoon käyttäen scikit-learn-kirjaston train_test_split-funktiota. Laita puolet aineistosta kumpaankin.
from sklearn.model_selection import train_test_split
X=df.drop("class identifier", axis=1)
y=df["class identifier"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1900)

# %%
#Normalisoi sarakkeet välille 0...1 scikit-learn-kirjaston preprocessing-moduulin minmax_scale-funktiolla.
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
df[["Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", "Total phenols", "Flavanoids",  "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline"]] = min_max_scaler.fit_transform(df[["Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", "Total phenols", "Flavanoids",  "Nonflavanoid phenols", "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines", "Proline"]])
df.tail()
# Out:
#      class identifier   Alcohol  Malic acid       Ash  Alcalinity of ash  \
# 172                 3  0.705263    0.970356  0.582888           0.510309
# 173                 3  0.623684    0.626482  0.598930           0.639175
# 174                 3  0.589474    0.699605  0.481283           0.484536
# 175                 3  0.563158    0.365613  0.540107           0.484536
# 176                 3  0.815789    0.664032  0.737968           0.716495
#
#      Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# 172   0.271739       0.241379    0.056962              0.735849
# 173   0.347826       0.282759    0.086498              0.566038
# 174   0.543478       0.210345    0.073840              0.566038
# 175   0.543478       0.231034    0.071730              0.754717
# 176   0.282609       0.368966    0.088608              0.811321
#
#      Proanthocyanins  Color intensity       Hue  OD280/OD315 of diluted wines  \
# 172         0.205047         0.547782  0.130081                      0.172161
# 173         0.315457         0.513652  0.178862                      0.106227
# 174         0.296530         0.761092  0.089431                      0.106227
# 175         0.331230         0.684300  0.097561                      0.128205
# 176         0.296530         0.675768  0.105691                      0.120879
#
#       Proline
# 172  0.329529
# 173  0.336662
# 174  0.397290
# 175  0.400856
# 176  0.201141

# %%
# Tehtävän vastaukset. Huom! Älä muokkaa tätä solua, vaan aja se, kun olet suorittanut tehtävän. 
# Tallenna vastauksesi X_train- X_test-muuttujiin.
print(f'X_train columns: {X_train.columns}')
print(f'X_train: {X_train}')
print(f'X_test: {X_test}')
# Out:
# X_train columns: Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')
# X_train:      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 119    11.45        2.40  2.42               20.0         96           2.90
# 145    13.88        5.04  2.23               20.0         80           0.98
# 131    12.81        2.31  2.40               24.0         98           1.15
# 121    12.42        4.43  2.73               26.5        102           2.20
# 175    13.17        2.59  2.37               20.0        120           1.65
# ..       ...         ...   ...                ...        ...            ...
# 147    13.32        3.24  2.38               21.5         92           1.93
# 47     14.10        2.02  2.40               18.8        103           2.75
# 61     13.67        1.25  1.92               18.0         94           2.10
# 124    12.07        2.16  2.17               21.0         85           2.60
# 15     14.30        1.92  2.72               20.0        120           2.80
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 119        2.79                  0.32             1.83             3.25  0.80
# 145        0.34                  0.40             0.68             4.90  0.58
# 131        1.09                  0.27             0.83             5.70  0.66
# 121        2.13                  0.43             1.71             2.08  0.92
# 175        0.68                  0.53             1.46             9.30  0.60
# ..          ...                   ...              ...              ...   ...
# 147        0.76                  0.45             1.25             8.42  0.55
# 47         2.92                  0.32             2.38             6.20  1.07
# 61         1.79                  0.32             0.73             3.80  1.23
# 124        2.65                  0.37             1.35             2.76  0.86
# 15         3.14                  0.33             1.97             6.20  1.07
#
#      OD280/OD315 of diluted wines  Proline
# 119                          3.39      625
# 145                          1.33      415
# 131                          1.36      560
# 121                          3.12      365
# 175                          1.62      840
# ..                            ...      ...
# 147                          1.62      650
# 47                           2.75     1060
# 61                           2.46      630
# 124                          3.28      378
# 15                           2.65     1280
#
# [118 rows x 13 columns]
# X_test:      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 134    12.60        2.46  2.20               18.5         94           1.62
# 62     12.37        1.13  2.16               19.0         87           3.50
# 43     13.05        1.77  2.10               17.0        107           3.00
# 79     12.00        0.92  2.00               19.0         86           2.42
# 69     12.29        1.61  2.21               20.4        103           1.10
# 169    12.20        3.03  2.32               19.0         96           1.25
# 13     14.38        1.87  2.38               12.0        102           3.30
# 33     13.51        1.80  2.65               19.0        110           2.35
# 8      13.86        1.35  2.27               16.0         98           2.98
# 116    12.42        1.61  2.19               22.5        108           2.00
# 59     12.33        1.10  2.28               16.0        101           2.05
# 129    12.86        1.35  2.32               18.0        122           1.51
# 53     13.74        1.67  2.25               16.4        118           2.60
# 122    13.05        5.80  2.13               21.5         86           2.62
# 166    12.82        3.37  2.30               19.5         88           1.48
# 136    12.53        5.51  2.64               25.0         96           1.79
# 45     14.38        3.59  2.28               16.0        102           3.25
# 18     13.64        3.10  2.56               15.2        116           2.70
# 30     13.58        1.66  2.36               19.1        106           2.86
# 173    13.40        3.91  2.48               23.0        102           1.80
# 162    12.96        3.45  2.35               18.5        106           1.39
# 176    14.13        4.10  2.74               24.5         96           2.05
# 20     12.93        3.80  2.65               18.6        102           2.41
# 163    13.78        2.76  2.30               22.0         90           1.35
# 102    11.82        1.72  1.88               19.5         86           2.50
# 137    13.49        3.59  2.19               19.5         88           1.62
# 112    11.41        0.74  2.50               21.0         88           2.48
# 34     13.48        1.81  2.41               20.5        100           2.70
# 49     13.05        1.73  2.04               12.4         92           2.72
# 57     13.72        1.43  2.50               16.7        108           3.40
# 95     11.81        2.12  2.74               21.5        134           1.60
# 76     11.84        2.89  2.23               18.0        112           1.72
# 146    12.87        4.61  2.48               21.5         86           1.70
# 25     13.39        1.77  2.62               16.1         93           2.85
# 11     13.75        1.73  2.41               16.0         89           2.60
# 126    11.79        2.13  2.78               28.5         92           2.13
# 36     13.05        1.65  2.55               18.0         98           2.45
# 60     12.64        1.36  2.02               16.8        100           2.02
# 7      14.83        1.64  2.17               14.0         97           2.80
# 44     14.21        4.04  2.44               18.9        111           2.85
# 77     12.33        0.99  1.95               14.8        136           1.90
# 133    12.51        1.24  2.25               17.5         85           2.00
# 32     13.76        1.53  2.70               19.5        132           2.95
# 46     13.90        1.68  2.12               16.0        101           3.10
# 157    14.34        1.68  2.70               25.0         98           2.80
# 117    12.77        3.43  1.98               16.0         80           1.63
# 29     13.73        1.50  2.70               22.5        101           3.00
# 38     14.22        3.99  2.51               13.2        128           3.00
# 154    13.17        5.19  2.32               22.0         93           1.74
# 71     13.49        1.66  2.24               24.0         87           1.88
# 55     14.22        1.70  2.30               16.3        118           3.20
# 161    12.85        3.27  2.58               22.0        106           1.65
# 70     13.86        1.51  2.67               25.0         86           2.95
# 14     13.63        1.81  2.70               17.2        112           2.85
# 140    13.36        2.56  2.35               20.0         89           1.40
# 3      13.24        2.59  2.87               21.0        118           2.80
# 130    12.88        2.99  2.40               20.0        104           1.30
# 26     13.30        1.72  2.14               17.0         94           2.40
# 118    12.00        3.43  2.00               19.0         87           2.00
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity  \
# 134        0.66                  0.63             0.94             7.10
# 62         3.10                  0.19             1.87             4.45
# 43         3.00                  0.28             2.03             5.04
# 79         2.26                  0.30             1.43             2.50
# 69         1.02                  0.37             1.46             3.05
# 169        0.49                  0.40             0.73             5.50
# 13         3.64                  0.29             2.96             7.50
# 33         2.53                  0.29             1.54             4.20
# 8          3.15                  0.22             1.85             7.22
# 116        2.09                  0.34             1.61             2.06
# 59         1.09                  0.63             0.41             3.27
# 129        1.25                  0.21             0.94             4.10
# 53         2.90                  0.21             1.62             5.85
# 122        2.65                  0.30             2.01             2.60
# 166        0.66                  0.40             0.97            10.26
# 136        0.60                  0.63             1.10             5.00
# 45         3.17                  0.27             2.19             4.90
# 18         3.03                  0.17             1.66             5.10
# 30         3.19                  0.22             1.95             6.90
# 173        0.75                  0.43             1.41             7.30
# 162        0.70                  0.40             0.94             5.28
# 176        0.76                  0.56             1.35             9.20
# 20         2.41                  0.25             1.98             4.50
# 163        0.68                  0.41             1.03             9.58
# 102        1.64                  0.37             1.42             2.06
# 137        0.48                  0.58             0.88             5.70
# 112        2.01                  0.42             1.44             3.08
# 34         2.98                  0.26             1.86             5.10
# 49         3.27                  0.17             2.91             7.20
# 57         3.67                  0.19             2.04             6.80
# 95         0.99                  0.14             1.56             2.50
# 76         1.32                  0.43             0.95             2.65
# 146        0.65                  0.47             0.86             7.65
# 25         2.94                  0.34             1.45             4.80
# 11         2.76                  0.29             1.81             5.60
# 126        2.24                  0.58             1.76             3.00
# 36         2.43                  0.29             1.44             4.25
# 60         1.41                  0.53             0.62             5.75
# 7          2.98                  0.29             1.98             5.20
# 44         2.65                  0.30             1.25             5.24
# 77         1.85                  0.35             2.76             3.40
# 133        0.58                  0.60             1.25             5.45
# 32         2.74                  0.50             1.35             5.40
# 46         3.39                  0.21             2.14             6.10
# 157        1.31                  0.53             2.70            13.00
# 117        1.25                  0.43             0.83             3.40
# 29         3.25                  0.29             2.38             5.70
# 38         3.04                  0.20             2.08             5.10
# 154        0.63                  0.61             1.55             7.90
# 71         1.84                  0.27             1.03             3.74
# 55         3.00                  0.26             2.03             6.38
# 161        0.60                  0.60             0.96             5.58
# 70         2.86                  0.21             1.87             3.38
# 14         2.91                  0.30             1.46             7.30
# 140        0.50                  0.37             0.64             5.60
# 3          2.69                  0.39             1.82             4.32
# 130        1.22                  0.24             0.83             5.40
# 26         2.19                  0.27             1.35             3.95
# 118        1.64                  0.37             1.87             1.28
#
#        Hue  OD280/OD315 of diluted wines  Proline
# 134  0.730                          1.58      695
# 62   1.220                          2.87      420
# 43   0.880                          3.35      885
# 79   1.380                          3.12      278
# 69   0.906                          1.82      870
# 169  0.660                          1.83      510
# 13   1.200                          3.00     1547
# 33   1.100                          2.87     1095
# 8    1.010                          3.55     1045
# 116  1.060                          2.96      345
# 59   1.250                          1.67      680
# 129  0.760                          1.29      630
# 53   0.920                          3.20     1060
# 122  0.730                          3.10      380
# 166  0.720                          1.75      685
# 136  0.820                          1.69      515
# 45   1.040                          3.44     1065
# 18   0.960                          3.36      845
# 30   1.090                          2.88     1515
# 173  0.700                          1.56      750
# 162  0.680                          1.75      675
# 176  0.610                          1.60      560
# 20   1.030                          3.52      770
# 163  0.700                          1.68      615
# 102  0.940                          2.44      415
# 137  0.810                          1.82      580
# 112  1.100                          2.31      434
# 34   1.040                          3.47      920
# 49   1.120                          2.91     1150
# 57   0.890                          2.87     1285
# 95   0.950                          2.26      625
# 76   0.960                          2.52      500
# 146  0.540                          1.86      625
# 25   0.920                          3.22     1195
# 11   1.150                          2.90     1320
# 126  0.970                          2.44      466
# 36   1.120                          2.51     1105
# 60   0.980                          1.59      450
# 7    1.080                          2.85     1045
# 44   0.870                          3.33     1080
# 77   1.060                          2.31      750
# 133  0.750                          1.51      650
# 32   1.250                          3.00     1235
# 46   0.910                          3.33      985
# 157  0.570                          1.96      660
# 117  0.700                          2.12      372
# 29   1.190                          2.71     1285
# 38   0.890                          3.53      760
# 154  0.600                          1.48      725
# 71   0.980                          2.78      472
# 55   0.940                          3.31      970
# 161  0.870                          2.11      570
# 70   1.360                          3.16      410
# 14   1.280                          2.88     1310
# 140  0.700                          2.47      780
# 3    1.040                          2.93      735
# 130  0.740                          1.42      530
# 26   1.020                          2.77     1285
# 118  0.930                          3.05      564

# %% [markdown]
# ## Tehtävä 2
# ### Aihe: Gaussian Naive Bayes
#
# 2 pistettä
#
# Käytä `scikit-learn`-kirjastosta löytyvää *Gaussian Naive Bayes* -menetelmää aineiston luokittelemiseksi.
#
# Ennnusta testiaineiston luokka. Tallenna ennusteet `y_pred`-muuttujaan.

# %%
# Kirjoita toteutuksesi tähän soluun.

# %%
# Kirjoita toteutuksesi tähän soluun. 
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)

# %%
# Tehtävän vastaukset. Huom! Älä muokkaa tätä solua, vaan aja se, kun olet suorittanut tehtävän. 
# Tallenna ennusteen tulokset y_pred-muuttujaan.
print(f'{len(y_pred)}')
# Out:
# 59

# %% [markdown]
# ## Tehtävä 3
# ### Aihe: Tarkkuuden mittaaminen
#
# 4 pistettä
#
# Hyödynnä `scikit-learn`-kirjaston `metrics`-moduulin funktioita ja laske luokittelutuloksesi **tarkkuus** sekä **sekaannusmatriisi**. Tallenna tarkkuus muuttujaan `acc` ja sekaannusmatriisi muuttujaan `cm`.
#
# Vinkki: onnistumista voit mitata ainoastaa testiaineiston osalta!

# %%
from sklearn.metrics import confusion_matrix

# %%
# Kirjoita toteutuksesi tähän soluun. 
acc=gnb.score(X_test, y_test)
cm=confusion_matrix(y_test, y_pred)

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9661016949152542

# %%
# Tehtävän vastaukset. Huom! Älä muokkaa tätä solua, vaan aja se, kun olet suorittanut tehtävän. 
# Tallenna vastauksesi acc- ja cm-muuttujiin.
print(f'Accuracy: {acc}')
print(f'Confusion matrix:\n {cm}')
# Out:
# Accuracy: 0.9661016949152542
# Confusion matrix:
#  [[24  1  0]
#  [ 0 16  1]
#  [ 0  0 17]]
